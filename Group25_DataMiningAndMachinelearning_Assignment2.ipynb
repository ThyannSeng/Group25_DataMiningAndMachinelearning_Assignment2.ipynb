# %% [markdown]
# <a href="https://colab.research.google.com/github/ThyannSeng/Group25_DataMiningAndMachinelearning_Assignment2.ipynb/blob/main/Group25_DataMiningAndMachinelearning_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Test Google Colab

# 1. Print a hello message
print("Hello from Google Colab!")

# 2. Simple computation
result = sum([i**2 for i in range(10)])
print("Sum of squares from 0 to 9:", result)

# 3. Plot a simple graph
import matplotlib.pyplot as plt

x = list(range(10))
y = [i**2 for i in x]

plt.plot(x, y, marker='o')
plt.title('Test Plot: y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
# Out:
# Hello from Google Colab!
# Sum of squares from 0 to 9: 285
